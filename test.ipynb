# %%
import sys, os

# %%
os.getcwd()
# Out:
# '/home/kunletoye/reseach/prob/utils'

# %%
os.chdir("./utils")

# %%
from utils import helper
import numpy as np

# %%
# !cat helper.ypoint()
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `cat helper.ypoint()'

# %%
x = np.linspace(990, 1200, 100)

# %%
helper.ypoint([990, 270, 1200, 288],x, 'linear_margin', 2*18 )
# Out:
# linear_margin
# array([455.14285714, 455.32467532, 455.50649351, 455.68831169,
#        455.87012987, 456.05194805, 456.23376623, 456.41558442,
#        456.5974026 , 456.77922078, 456.96103896, 457.14285714,
#        457.32467532, 457.50649351, 457.68831169, 457.87012987,
#        458.05194805, 458.23376623, 458.41558442, 458.5974026 ,
#        458.77922078, 458.96103896, 459.14285714, 459.32467532,
#        459.50649351, 459.68831169, 459.87012987, 460.05194805,
#        460.23376623, 460.41558442, 460.5974026 , 460.77922078,
#        460.96103896, 461.14285714, 461.32467532, 461.50649351,
#        461.68831169, 461.87012987, 462.05194805, 462.23376623,
#        462.41558442, 462.5974026 , 462.77922078, 462.96103896,
#        463.14285714, 463.32467532, 463.50649351, 463.68831169,
#        463.87012987, 464.05194805, 464.23376623, 464.41558442,
#        464.5974026 , 464.77922078, 464.96103896, 465.14285714,
#        465.32467532, 465.50649351, 465.68831169, 465.87012987,
# ...

# %%
line = [990, 270, 1200, 288]
slope = (line[3] - line[1])/(line[2] - line[0])
intercept = line[1] - slope * line[0]

# %%
x * slope + intercept + 36
# Out:
# array([306.        , 306.18181818, 306.36363636, 306.54545455,
#        306.72727273, 306.90909091, 307.09090909, 307.27272727,
#        307.45454545, 307.63636364, 307.81818182, 308.        ,
#        308.18181818, 308.36363636, 308.54545455, 308.72727273,
#        308.90909091, 309.09090909, 309.27272727, 309.45454545,
#        309.63636364, 309.81818182, 310.        , 310.18181818,
#        310.36363636, 310.54545455, 310.72727273, 310.90909091,
#        311.09090909, 311.27272727, 311.45454545, 311.63636364,
#        311.81818182, 312.        , 312.18181818, 312.36363636,
#        312.54545455, 312.72727273, 312.90909091, 313.09090909,
#        313.27272727, 313.45454545, 313.63636364, 313.81818182,
#        314.        , 314.18181818, 314.36363636, 314.54545455,
#        314.72727273, 314.90909091, 315.09090909, 315.27272727,
#        315.45454545, 315.63636364, 315.81818182, 316.        ,
#        316.18181818, 316.36363636, 316.54545455, 316.72727273,
# ...

# %%
        <!-- <form>
            <table class="table">
                <tr>
                    <td><label for="endpoints1">Line 1:</label></td>
                    <td><label for="endpoints2">Line 2:</label></td>
                </tr>
                <tr>
                    <td><input type="text" id="field1" placeholder="x1, y1, x2, y2"></td>
                    <td><input type="text" id="field2" placeholder="x1, y1, x2, y2"></td>
                </tr>
            </table>
            <input type="submit" value="Submit">
            <input type="reset" value="Reset">
        </form>
